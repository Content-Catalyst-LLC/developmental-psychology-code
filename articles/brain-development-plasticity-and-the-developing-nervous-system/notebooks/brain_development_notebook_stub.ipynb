# %% [markdown]
# # Brain Development, Plasticity, and the Developing Nervous System\n\nRun the Python scripts first, then load the synthetic panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/brain_development_panel.csv')\npanel.head()
