# %% [markdown]
# # Adult Development and the Psychology of Life Stages
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
panel = pd.read_csv('../data/adult_development_life_stages_panel.csv')
panel.head()
