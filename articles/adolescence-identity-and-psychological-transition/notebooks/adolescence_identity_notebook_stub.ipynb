# %% [markdown]
# # Adolescence, Identity, and Psychological Transition\n\nRun the Python scripts first, then load the synthetic panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/adolescence_identity_panel.csv')\npanel.head()
