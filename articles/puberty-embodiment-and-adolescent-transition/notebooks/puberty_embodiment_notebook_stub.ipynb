# %% [markdown]
# # Puberty, Embodiment, and Adolescent Transition\n\nRun the Python scripts first, then load the synthetic panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/puberty_embodiment_panel.csv')\npanel.head()
