# %% [markdown]
# # Gender Development and Sexual Development
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
panel = pd.read_csv('../data/gender_sexual_development_panel.csv')
panel.head()
