# %% [markdown]
# # What Is Developmental Psychology?\n\nRun the Python scripts first, then load the synthetic developmental lifespan panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/developmental_lifespan_panel.csv')\npanel.head()
