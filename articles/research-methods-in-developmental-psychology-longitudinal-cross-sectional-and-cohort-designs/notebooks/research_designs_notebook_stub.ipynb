# %% [markdown]
# # Research Methods in Developmental Psychology\n\nThis notebook scaffold supports exploratory work on longitudinal, cross-sectional, cohort, and cohort-sequential designs. Run the scripts in `python/` and `r/` first for reproducible outputs.

# %%
import pandas as pd\npanel = pd.read_csv('../data/developmental_design_panel.csv')\npanel.head()
