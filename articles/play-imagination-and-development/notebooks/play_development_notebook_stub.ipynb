# %% [markdown]
# # Play, Imagination, and Development\n\nRun the Python scripts first, then load the synthetic play-development panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/play_development_panel.csv')\npanel.head()
