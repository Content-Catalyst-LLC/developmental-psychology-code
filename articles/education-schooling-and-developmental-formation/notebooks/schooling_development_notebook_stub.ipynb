# %% [markdown]
# # Education, Schooling, and Developmental Formation
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
panel = pd.read_csv('../data/schooling_development_panel.csv')
panel.head()
