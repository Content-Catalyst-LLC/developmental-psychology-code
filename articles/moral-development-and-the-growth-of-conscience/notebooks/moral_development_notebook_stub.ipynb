# %% [markdown]
# # Moral Development and the Growth of Conscience\n\nRun the Python scripts first, then load the synthetic moral-development panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/moral_development_panel.csv')\npanel.head()
