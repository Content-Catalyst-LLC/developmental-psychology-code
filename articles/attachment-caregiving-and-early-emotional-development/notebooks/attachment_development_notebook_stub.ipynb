# %% [markdown]
# # Attachment, Caregiving, and Early Emotional Development\n\nRun the Python scripts first, then load the synthetic attachment-development panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/attachment_development_panel.csv')\npanel.head()
