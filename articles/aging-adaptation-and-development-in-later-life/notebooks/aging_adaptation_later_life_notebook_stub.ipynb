# %% [markdown]
# # Aging, Adaptation, and Development in Later Life
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
panel = pd.read_csv('../data/aging_adaptation_later_life_panel.csv')
panel.head()
