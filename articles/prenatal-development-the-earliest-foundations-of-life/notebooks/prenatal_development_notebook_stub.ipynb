# %% [markdown]
# # Prenatal Development: The Earliest Foundations of Life
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
prenatal = pd.read_csv('../data/prenatal_development_foundations_panel.csv')
prenatal.head()
