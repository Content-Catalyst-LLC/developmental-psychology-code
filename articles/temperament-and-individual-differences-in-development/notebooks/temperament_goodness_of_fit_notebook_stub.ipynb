# %% [markdown]
# # Temperament and Individual Differences in Development
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
panel = pd.read_csv('../data/temperament_individual_differences_panel.csv')
panel.head()
