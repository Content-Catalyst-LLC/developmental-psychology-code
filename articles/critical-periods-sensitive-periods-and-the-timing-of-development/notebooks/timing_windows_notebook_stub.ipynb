# %% [markdown]
# # Critical Periods, Sensitive Periods, and Developmental Timing\n\nThis notebook scaffold supports exploratory analysis. Run the scripts in `python/` and `r/` first for reproducible outputs.

# %%
import pandas as pd\npanel = pd.read_csv('../data/developmental_timing_panel.csv')\npanel.head()
