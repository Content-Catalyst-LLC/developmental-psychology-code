# %% [markdown]
# # Development, Inequality, and the Life Course\n\nRun the scripts in `python/` and `r/` first, then use this notebook for exploratory analysis.

# %%
import pandas as pd\npanel = pd.read_csv('../data/life_course_inequality_panel.csv')\npanel.head()
