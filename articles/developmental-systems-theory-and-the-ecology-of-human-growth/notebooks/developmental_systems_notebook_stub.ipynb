# %% [markdown]
# # Developmental Systems Theory and the Ecology of Human Growth
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
panel = pd.read_csv('../data/developmental_systems_panel.csv')
panel.head()
