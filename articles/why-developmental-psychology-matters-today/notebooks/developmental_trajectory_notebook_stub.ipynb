# %% [markdown]
# # Why Developmental Psychology Matters Today\n\nThis notebook scaffold is intentionally minimal. Run the scripts in `python/` and `r/` for reproducible workflows, then use this notebook for exploratory analysis.

# %%
import pandas as pd\npanel = pd.read_csv('../data/developmental_panel.csv')\npanel.head()
