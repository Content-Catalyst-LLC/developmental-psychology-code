# %% [markdown]
# # Parenting, Family Systems, and Human Development
#
# Run the Python scripts first, then use this notebook for exploratory analysis.

# %%
import pandas as pd
panel = pd.read_csv('../data/family_systems_panel.csv')
panel.head()
