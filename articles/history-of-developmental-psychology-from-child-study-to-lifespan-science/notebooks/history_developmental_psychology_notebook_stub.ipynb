# %% [markdown]
# # History of Developmental Psychology\n\nRun the Python scripts first, then load the synthetic history panel.

# %%
import pandas as pd\npanel = pd.read_csv('../data/developmental_psychology_history_panel.csv')\npanel.head()
